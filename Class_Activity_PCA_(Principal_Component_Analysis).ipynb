# %% [markdown]
# <a href="https://colab.research.google.com/github/CliffAD/CAD-Projects/blob/main/Class_Activity_PCA_(Principal_Component_Analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clifford Anthony Dsouza                                    Date : 25.03.2026
# Bachelor's STEM Program German Track
# Lab Class_Activity_PCA (Principal Component Analysis)
# STEP 1: Import Required Libraries
# ==============================

print("Hello Data 110 Machine Learning NLP - 'Principal 'Component 'Analysis (PCA).")
print("Student Name: Clifford Anthony Dsouza.")
print("Professor - Dr. Durga Sharma.")

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import warnings
# Out:
# Hello Data 110 Machine Learning NLP - 'Principal 'Component 'Analysis (PCA).
# Student Name: Clifford Anthony Dsouza.
# Professor - Dr. Durga Sharma.

# %%
# STEP 2: Load Dataset

from sklearn.datasets import load_wine
data = load_wine()

#  Fill here
X = data.data
y = data.target

# %%
# STEP 3: Split the Dataset

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# STEP 4: Standardize the Data

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

#  Fill here
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# PART A: BEFORE PCA

from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
print("----- BEFORE PCA -----")

knn = KNeighborsClassifier(n_neighbors=5)

# Fill here
knn.fit(X_train_scaled, y_train)

y_pred_before = knn.predict(X_test_scaled)
acc_before = accuracy_score(y_test, y_pred_before)

print("Accuracy BEFORE PCA:", acc_before)
# Out:
# ----- BEFORE PCA -----
# Accuracy BEFORE PCA: 0.9629629629629629

# %%
# PART B: APPLY PCA
# ==============================

pca = PCA(n_components=2)

# Fill here
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
# PART B: APPLY PCA
# ==============================

pca = PCA(n_components=2)

# Fill here
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
# PART C: AFTER PCA
# ==============================

# Train KNN on PCA-transformed data

print("----- AFTER PCA -----")

knn_pca = KNeighborsClassifier(n_neighbors=5)
knn_pca.fit(X_train_pca, y_train)

y_pred_after = knn_pca.predict(X_test_pca)
acc_after = accuracy_score(y_test, y_pred_after)

print("Accuracy AFTER PCA:", acc_after)
# Out:
# ----- AFTER PCA -----
# Accuracy AFTER PCA: 0.9814814814814815

# %%
# BONUS: Explained Variance

print("\nExplained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.36196226 0.18763862]
