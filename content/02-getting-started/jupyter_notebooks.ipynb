# %% [markdown]
# <a href="https://colab.research.google.com/github/CliffAD/CAD-Projects/blob/main/content/02-getting-started/jupyter_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clifford Anthony Dsouza                                    Date : 25.03.2026
# Bachelor's STEM Program German Track
# Lab Class_Activity_PCA (Principal Component Analysis)
# STEP 1: Import Required Libraries
# ==============================

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import -------------
from sklearn.metrics import accuracy_score

# %%
# STEP 2: Load Dataset

data = load_wine()

#  Fill here
X = data.data
y = data.target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1337/4145850690.py in <cell line: 0>()
#       1 # STEP 2: Load Dataset
#       2
# ----> 3 data = load_wine()
#       4
#       5 #  Fill here
#
# NameError: name 'load_wine' is not defined
